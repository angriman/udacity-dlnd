# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 1
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 1:
# Image - Min Value: 1 Max Value: 244
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    min_value, max_value = x.min(), x.max()
    return (x - min_value) / (max_value - min_value)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    numberOfClasses = 10
    
    # Initializing encoded labels
    encoded_labels = np.zeros((len(x), 10))
    #for i in range(len(x)):
    #    encoded_labels[i][x[i]] = 1
    
    # More efficient implementation. Thank you for the suggestion,
    # I was not aware of this convenient numpy function
    encoded_labels[np.arange(len(x)), x] = 1
    
    return encoded_labels


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shape = (None,) + image_shape
    return tf.placeholder(tf.float32, shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    shape = (None, n_classes)
    return tf.placeholder(tf.float32, shape, name="y")



def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function

    # Dimensions of the filter
    inputHeight = int(x_tensor.shape[1])
    inputWidth = int(x_tensor.shape[2])
    inputDepth = int(x_tensor.shape[3])
    
    # Creating weights and bias
    wShape = list(conv_ksize) + [inputDepth, conv_num_outputs]
    weights = tf.Variable(tf.truncated_normal(wShape, stddev=0.1))
    bias = tf.Variable(tf.random_uniform([conv_num_outputs], 0, 0.1))
    
    # Creating strides vector
    strides = [1] + list(conv_strides) + [1]

    # Applying convolution and adding bias
    conv_tensor = tf.nn.conv2d(\
            x_tensor, weights, strides, padding='SAME')\
            + bias

    # Adding activation function
    conv_tensor = tf.nn.relu(conv_tensor)

    # Creating strides and ksize for pooling
    strides = [1] + list(pool_strides) + [1]
    ksize = [1] + list(pool_ksize) + [1]
    
    # Applying max pool
    conv_tensor = tf.nn.max_pool(\
            conv_tensor, ksize, strides, 'SAME')
    
    return conv_tensor 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    # Dimensions of the tensor
    dims = x_tensor.get_shape().as_list()
    
    # Computing second dimension as the product
    # of the x_tensor dimensions (exluding the batches)
    x = 1
    for i in dims[1:]:
        x *= int(i)
        
    # Creating the flattened tensor
    newShape = [-1, x]
    x_tensor = tf.reshape(x_tensor, newShape)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ## Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    # Creating weights and bias. Using 0.1 as standard
    # deviation and variance.
    dim = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal((\
            dim, num_outputs),\
            stddev=0.1))

    bias = tf.Variable(tf.random_uniform([num_outputs], 0, 0.1))

    # Applying the fully connected layer
    result = tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), bias))
    
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    # Input dimension
    dim = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal((\
            dim, num_outputs),\
            stddev=0.1))

    bias = tf.Variable(tf.random_uniform([num_outputs], 0, 0.1))
    x_tensor = tf.add(tf.matmul(x_tensor, weights), bias)

    return x_tensor

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Number of classes in our dataset
    numberOfClasses = 10
    
    
    ###### Convolution and Max Pool layers ##### 
    
    ### Layer 1: 32x32x32 --> 16x16x8 ###
    conv_strides = (1,1)
    conv_ksize = (4,4)
   
    pool_ksize = (2,2)
    pool_strides = (2,2)
   
    conv_num_outputs = 8
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)    

    ### Layer 2: 16x16x8 --> 8x8x16 (Here I apply dropout) ###
    conv_num_outputs = 16
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = tf.nn.dropout(x, keep_prob)
    
    ### Layer 3: 8x8x16 --> 4x4x32 (+ dropout) ###
    conv_num_outputs = 32
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = tf.nn.dropout(x, keep_prob)

    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    
    ##### Fully Connected layers #####
    fullyConnDim = 1024
    # Layer 1:
    x = fully_conn(x, fullyConnDim)
    x = tf.nn.dropout(x, keep_prob)
    # Layer 2:
    x = fully_conn(x, fullyConnDim)
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    x = output(x, numberOfClasses)

    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={\
            x: feature_batch,\
            y: label_batch,\
            keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={\
                        x: feature_batch,\
                        y: label_batch,\
                        keep_prob: 1.0})
    validationAccuracy = session.run(accuracy, feed_dict={
                        x: valid_features,\
                        y: valid_labels,\
                        keep_prob: 1.0})
    
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(\
            loss, validationAccuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
# I am using a computing server (48 cores and 256 GB of ram), should I use an larger batch than this?
batch_size = 1024
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.4098 Validation Accuracy: 0.133800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2394 Validation Accuracy: 0.173000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.1149 Validation Accuracy: 0.232800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.0732 Validation Accuracy: 0.211800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.0157 Validation Accuracy: 0.277200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.9439 Validation Accuracy: 0.300000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.8747 Validation Accuracy: 0.330600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.8083 Validation Accuracy: 0.361200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.7734 Validation Accuracy: 0.365800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.7384 Validation Accuracy: 0.376800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.7071 Validation Accuracy: 0.380600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.6832 Validation Accuracy: 0.386400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.6428 Validation Accuracy: 0.403400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.6224 Validation Accuracy: 0.406400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.5850 Validation Accuracy: 0.423200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.5656 Validation Accuracy: 0.421400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.5379 Validation Accuracy: 0.426600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.5138 Validation Accuracy: 0.433800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.5122 Validation Accuracy: 0.426800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.5182 Validation Accuracy: 0.431200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.4980 Validation Accuracy: 0.440200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.4612 Validation Accuracy: 0.450800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.4412 Validation Accuracy: 0.456400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.4149 Validation Accuracy: 0.460400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.4011 Validation Accuracy: 0.468600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.3845 Validation Accuracy: 0.476800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.3694 Validation Accuracy: 0.477400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.3739 Validation Accuracy: 0.473600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.3342 Validation Accuracy: 0.477800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.3143 Validation Accuracy: 0.486800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.3103 Validation Accuracy: 0.481600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.2970 Validation Accuracy: 0.483600
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.2738 Validation Accuracy: 0.492000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.2550 Validation Accuracy: 0.499000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.2470 Validation Accuracy: 0.495400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.2363 Validation Accuracy: 0.500000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.2219 Validation Accuracy: 0.497800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.1997 Validation Accuracy: 0.508600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.1868 Validation Accuracy: 0.510400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.1648 Validation Accuracy: 0.513000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.1701 Validation Accuracy: 0.508200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.1372 Validation Accuracy: 0.517200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.1223 Validation Accuracy: 0.520800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.1138 Validation Accuracy: 0.519200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.1075 Validation Accuracy: 0.524200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.1235 Validation Accuracy: 0.509400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.1100 Validation Accuracy: 0.512800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.0843 Validation Accuracy: 0.514400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.0434 Validation Accuracy: 0.534200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.0529 Validation Accuracy: 0.533600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.0276 Validation Accuracy: 0.531400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.9945 Validation Accuracy: 0.537400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.9857 Validation Accuracy: 0.544000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.9626 Validation Accuracy: 0.544400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.9483 Validation Accuracy: 0.541000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.9288 Validation Accuracy: 0.545600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.9359 Validation Accuracy: 0.541600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.9200 Validation Accuracy: 0.550400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.9053 Validation Accuracy: 0.549400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.8914 Validation Accuracy: 0.551000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.8695 Validation Accuracy: 0.555400
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.8636 Validation Accuracy: 0.553200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.8475 Validation Accuracy: 0.559000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.8311 Validation Accuracy: 0.555600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.8255 Validation Accuracy: 0.560800
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.8127 Validation Accuracy: 0.564200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.8012 Validation Accuracy: 0.561600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.7788 Validation Accuracy: 0.564600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.7845 Validation Accuracy: 0.561400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.7611 Validation Accuracy: 0.567800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.7354 Validation Accuracy: 0.571200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.7323 Validation Accuracy: 0.569400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.7307 Validation Accuracy: 0.572600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.7071 Validation Accuracy: 0.570200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.6891 Validation Accuracy: 0.574400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.6851 Validation Accuracy: 0.574000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.6674 Validation Accuracy: 0.578400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.6669 Validation Accuracy: 0.578800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.6539 Validation Accuracy: 0.583600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.6438 Validation Accuracy: 0.579200
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.6218 Validation Accuracy: 0.582800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.6132 Validation Accuracy: 0.584000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.6018 Validation Accuracy: 0.578600
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.5852 Validation Accuracy: 0.581000
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.5667 Validation Accuracy: 0.583400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.5581 Validation Accuracy: 0.587000
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.5490 Validation Accuracy: 0.586200
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.5393 Validation Accuracy: 0.590200
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.5295 Validation Accuracy: 0.588000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.5206 Validation Accuracy: 0.590200
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.5153 Validation Accuracy: 0.595600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.5028 Validation Accuracy: 0.594400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.5040 Validation Accuracy: 0.590000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.5043 Validation Accuracy: 0.589200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.4773 Validation Accuracy: 0.593600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.4934 Validation Accuracy: 0.583600
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.4623 Validation Accuracy: 0.589000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.4494 Validation Accuracy: 0.590200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.4274 Validation Accuracy: 0.594000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.4252 Validation Accuracy: 0.589200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.6815 Validation Accuracy: 0.107800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2957 Validation Accuracy: 0.099800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.2464 Validation Accuracy: 0.169800
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.1640 Validation Accuracy: 0.191200
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.0005 Validation Accuracy: 0.265400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9450 Validation Accuracy: 0.298200
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.8589 Validation Accuracy: 0.327600
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.7661 Validation Accuracy: 0.351400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.7414 Validation Accuracy: 0.359400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.7242 Validation Accuracy: 0.358400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7077 Validation Accuracy: 0.388400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.6666 Validation Accuracy: 0.394200
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.5523 Validation Accuracy: 0.422000
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.5530 Validation Accuracy: 0.428600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5650 Validation Accuracy: 0.427000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5528 Validation Accuracy: 0.460800
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.5427 Validation Accuracy: 0.448000
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.4199 Validation Accuracy: 0.469800
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.4094 Validation Accuracy: 0.478200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.4439 Validation Accuracy: 0.469800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4549 Validation Accuracy: 0.481200
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.4335 Validation Accuracy: 0.488800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.3274 Validation Accuracy: 0.498200
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.3360 Validation Accuracy: 0.505800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.3900 Validation Accuracy: 0.483600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3738 Validation Accuracy: 0.504000
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.3670 Validation Accuracy: 0.510600
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.2884 Validation Accuracy: 0.512600
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.2791 Validation Accuracy: 0.512800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.3217 Validation Accuracy: 0.508600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3099 Validation Accuracy: 0.521200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.3092 Validation Accuracy: 0.531600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.2435 Validation Accuracy: 0.524200
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.2177 Validation Accuracy: 0.530600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.2481 Validation Accuracy: 0.528800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2443 Validation Accuracy: 0.544000
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.2623 Validation Accuracy: 0.535600
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.2089 Validation Accuracy: 0.532000
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.1752 Validation Accuracy: 0.550600
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.2180 Validation Accuracy: 0.535800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.2120 Validation Accuracy: 0.546600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.2114 Validation Accuracy: 0.553600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.1623 Validation Accuracy: 0.545400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.1396 Validation Accuracy: 0.562000
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.1758 Validation Accuracy: 0.545600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1697 Validation Accuracy: 0.559400
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.1837 Validation Accuracy: 0.563600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.1651 Validation Accuracy: 0.546600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.1334 Validation Accuracy: 0.564000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.1461 Validation Accuracy: 0.557600
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.1291 Validation Accuracy: 0.568200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.1457 Validation Accuracy: 0.573000
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.0956 Validation Accuracy: 0.566800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.0731 Validation Accuracy: 0.578200
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.1055 Validation Accuracy: 0.567600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.1066 Validation Accuracy: 0.577400
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.1223 Validation Accuracy: 0.585200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.0616 Validation Accuracy: 0.573200
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.0522 Validation Accuracy: 0.582200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.0655 Validation Accuracy: 0.581400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.0790 Validation Accuracy: 0.588600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.0922 Validation Accuracy: 0.593800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.0314 Validation Accuracy: 0.584000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.0147 Validation Accuracy: 0.598800
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.0242 Validation Accuracy: 0.586800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.0415 Validation Accuracy: 0.604200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.0618 Validation Accuracy: 0.602800
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.9968 Validation Accuracy: 0.591000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.9970 Validation Accuracy: 0.608800
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.0002 Validation Accuracy: 0.591000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.0213 Validation Accuracy: 0.609800
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.0396 Validation Accuracy: 0.605200
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.9782 Validation Accuracy: 0.597600
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.9631 Validation Accuracy: 0.617000
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.9586 Validation Accuracy: 0.602400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.9915 Validation Accuracy: 0.619200
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.0124 Validation Accuracy: 0.614400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.9350 Validation Accuracy: 0.612200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.9441 Validation Accuracy: 0.624800
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.9412 Validation Accuracy: 0.611800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.9750 Validation Accuracy: 0.627000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.9867 Validation Accuracy: 0.621200
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.9192 Validation Accuracy: 0.620000
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.9225 Validation Accuracy: 0.631000
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.9148 Validation Accuracy: 0.613200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.9471 Validation Accuracy: 0.633600
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.9746 Validation Accuracy: 0.630600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.9007 Validation Accuracy: 0.619600
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.9091 Validation Accuracy: 0.636400
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.8891 Validation Accuracy: 0.619200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.9232 Validation Accuracy: 0.636800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.9532 Validation Accuracy: 0.640200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.8834 Validation Accuracy: 0.628200
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.8900 Validation Accuracy: 0.638600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.8564 Validation Accuracy: 0.634000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.9166 Validation Accuracy: 0.641800
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.9297 Validation Accuracy: 0.641400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.8545 Validation Accuracy: 0.635600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.8617 Validation Accuracy: 0.644000
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.8435 Validation Accuracy: 0.628800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.8955 Validation Accuracy: 0.642600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.9289 Validation Accuracy: 0.638600
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.8357 Validation Accuracy: 0.642400
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.8654 Validation Accuracy: 0.644600
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.8164 Validation Accuracy: 0.642000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.8672 Validation Accuracy: 0.650000
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.9104 Validation Accuracy: 0.643000
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.8214 Validation Accuracy: 0.647600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.8294 Validation Accuracy: 0.652600
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.7988 Validation Accuracy: 0.638800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.8661 Validation Accuracy: 0.646400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.8762 Validation Accuracy: 0.651400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.8176 Validation Accuracy: 0.643800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.8053 Validation Accuracy: 0.661800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.7803 Validation Accuracy: 0.651200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.8262 Validation Accuracy: 0.663200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.8611 Validation Accuracy: 0.656200
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.8028 Validation Accuracy: 0.646000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.7969 Validation Accuracy: 0.659200
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.7675 Validation Accuracy: 0.646000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.8184 Validation Accuracy: 0.657400
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.8720 Validation Accuracy: 0.644400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.8338 Validation Accuracy: 0.637800
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.7864 Validation Accuracy: 0.658600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.7579 Validation Accuracy: 0.651600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.8028 Validation Accuracy: 0.666800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.8440 Validation Accuracy: 0.660600
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.7857 Validation Accuracy: 0.653200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.7672 Validation Accuracy: 0.662400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.7324 Validation Accuracy: 0.665800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.7749 Validation Accuracy: 0.672800
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.8308 Validation Accuracy: 0.661400
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.7595 Validation Accuracy: 0.658800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.7585 Validation Accuracy: 0.669200
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.7144 Validation Accuracy: 0.667200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.7519 Validation Accuracy: 0.678600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.8130 Validation Accuracy: 0.661400
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.7716 Validation Accuracy: 0.653600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.7442 Validation Accuracy: 0.665800
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.7214 Validation Accuracy: 0.662000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.7279 Validation Accuracy: 0.684200
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.7819 Validation Accuracy: 0.676000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.7444 Validation Accuracy: 0.656800
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.7243 Validation Accuracy: 0.676200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.6979 Validation Accuracy: 0.670400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.7112 Validation Accuracy: 0.687200
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.7810 Validation Accuracy: 0.675400
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.7328 Validation Accuracy: 0.662400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.7265 Validation Accuracy: 0.677600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.6873 Validation Accuracy: 0.675200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.6975 Validation Accuracy: 0.688400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.7583 Validation Accuracy: 0.674400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.7405 Validation Accuracy: 0.658600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.7004 Validation Accuracy: 0.677000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.6681 Validation Accuracy: 0.670000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.6970 Validation Accuracy: 0.683400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.7560 Validation Accuracy: 0.675400
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.6867 Validation Accuracy: 0.676600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.6853 Validation Accuracy: 0.685000
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.6602 Validation Accuracy: 0.665200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.6890 Validation Accuracy: 0.688800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.7264 Validation Accuracy: 0.688200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.6671 Validation Accuracy: 0.681200
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.6671 Validation Accuracy: 0.684600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.6479 Validation Accuracy: 0.667000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.6656 Validation Accuracy: 0.687800
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.7222 Validation Accuracy: 0.687200
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.6718 Validation Accuracy: 0.683600
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.6565 Validation Accuracy: 0.690800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.6283 Validation Accuracy: 0.675600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.6621 Validation Accuracy: 0.693600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.7112 Validation Accuracy: 0.688400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.6777 Validation Accuracy: 0.675600
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.6517 Validation Accuracy: 0.684600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.6384 Validation Accuracy: 0.672400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.6396 Validation Accuracy: 0.696800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.7152 Validation Accuracy: 0.683800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.6546 Validation Accuracy: 0.686000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.6168 Validation Accuracy: 0.698200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.5894 Validation Accuracy: 0.690800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.6274 Validation Accuracy: 0.699600
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.6860 Validation Accuracy: 0.693200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.6210 Validation Accuracy: 0.690600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.6040 Validation Accuracy: 0.695600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.5821 Validation Accuracy: 0.686600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.6143 Validation Accuracy: 0.697400
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.6756 Validation Accuracy: 0.688600
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.6110 Validation Accuracy: 0.695000
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.5876 Validation Accuracy: 0.702800
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.5775 Validation Accuracy: 0.688000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.6028 Validation Accuracy: 0.696800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.6730 Validation Accuracy: 0.691000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.6270 Validation Accuracy: 0.688400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.5782 Validation Accuracy: 0.705600
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.5617 Validation Accuracy: 0.693800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.5737 Validation Accuracy: 0.704000
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.6379 Validation Accuracy: 0.701200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.6105 Validation Accuracy: 0.687000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.5751 Validation Accuracy: 0.701600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.5509 Validation Accuracy: 0.696000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.5634 Validation Accuracy: 0.710600
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.6165 Validation Accuracy: 0.698400
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.6054 Validation Accuracy: 0.686400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.5552 Validation Accuracy: 0.704400
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.5510 Validation Accuracy: 0.692000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.5600 Validation Accuracy: 0.706600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.6151 Validation Accuracy: 0.700000
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.5912 Validation Accuracy: 0.690200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.5525 Validation Accuracy: 0.701200
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.5424 Validation Accuracy: 0.696600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.5608 Validation Accuracy: 0.705800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.6138 Validation Accuracy: 0.705200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.5844 Validation Accuracy: 0.693600
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.5480 Validation Accuracy: 0.699600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.5329 Validation Accuracy: 0.696200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.5415 Validation Accuracy: 0.711400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.6115 Validation Accuracy: 0.699400
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.5965 Validation Accuracy: 0.679400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.5465 Validation Accuracy: 0.690800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.5254 Validation Accuracy: 0.698600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.5647 Validation Accuracy: 0.700600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.5979 Validation Accuracy: 0.703600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.5304 Validation Accuracy: 0.700400
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.5355 Validation Accuracy: 0.701000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.4814 Validation Accuracy: 0.710000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.5222 Validation Accuracy: 0.712000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.5849 Validation Accuracy: 0.710000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.5306 Validation Accuracy: 0.700600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.5128 Validation Accuracy: 0.705200
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.4828 Validation Accuracy: 0.697400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.5193 Validation Accuracy: 0.713200
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.5557 Validation Accuracy: 0.710800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.5240 Validation Accuracy: 0.701400
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.4865 Validation Accuracy: 0.711800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.4780 Validation Accuracy: 0.699400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.5363 Validation Accuracy: 0.708400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.5560 Validation Accuracy: 0.706600
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.4878 Validation Accuracy: 0.717400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.4956 Validation Accuracy: 0.707400
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.4498 Validation Accuracy: 0.708400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.4947 Validation Accuracy: 0.713000
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.5463 Validation Accuracy: 0.710400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.4837 Validation Accuracy: 0.715600
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.4862 Validation Accuracy: 0.711400
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.4440 Validation Accuracy: 0.710200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.4723 Validation Accuracy: 0.720000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.5253 Validation Accuracy: 0.713400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.4765 Validation Accuracy: 0.716600
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.4716 Validation Accuracy: 0.710600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.4398 Validation Accuracy: 0.709000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.4691 Validation Accuracy: 0.715800
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.5156 Validation Accuracy: 0.714400
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.4966 Validation Accuracy: 0.707600
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.4440 Validation Accuracy: 0.720600
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.4276 Validation Accuracy: 0.717600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.4583 Validation Accuracy: 0.719600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.4949 Validation Accuracy: 0.713000
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.4434 Validation Accuracy: 0.724200
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.4546 Validation Accuracy: 0.711800
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.4237 Validation Accuracy: 0.710400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.4263 Validation Accuracy: 0.726000
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.4846 Validation Accuracy: 0.721000
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.4540 Validation Accuracy: 0.715000
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.4253 Validation Accuracy: 0.721000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.4157 Validation Accuracy: 0.710800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.4270 Validation Accuracy: 0.725800
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.4901 Validation Accuracy: 0.716600
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.4345 Validation Accuracy: 0.721800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.4152 Validation Accuracy: 0.722400
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.3819 Validation Accuracy: 0.715000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.4225 Validation Accuracy: 0.723600
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.4767 Validation Accuracy: 0.711600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.4331 Validation Accuracy: 0.722400
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.4091 Validation Accuracy: 0.719000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.3793 Validation Accuracy: 0.715800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.4059 Validation Accuracy: 0.725400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.4508 Validation Accuracy: 0.719600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.4204 Validation Accuracy: 0.719600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.3994 Validation Accuracy: 0.716400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.3719 Validation Accuracy: 0.711200
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.4160 Validation Accuracy: 0.721000
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.4470 Validation Accuracy: 0.719400
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.4184 Validation Accuracy: 0.723400
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.3870 Validation Accuracy: 0.719000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.3589 Validation Accuracy: 0.716400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.3919 Validation Accuracy: 0.724200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.4222 Validation Accuracy: 0.725000
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.3972 Validation Accuracy: 0.724400
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.3818 Validation Accuracy: 0.720200
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.3491 Validation Accuracy: 0.721000
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.3945 Validation Accuracy: 0.723200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.4502 Validation Accuracy: 0.712600
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.3957 Validation Accuracy: 0.717800
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.3731 Validation Accuracy: 0.718600
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.3754 Validation Accuracy: 0.714400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.4194 Validation Accuracy: 0.714200
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.4186 Validation Accuracy: 0.729200
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.3954 Validation Accuracy: 0.726200
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.3895 Validation Accuracy: 0.710400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.3354 Validation Accuracy: 0.723600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.3705 Validation Accuracy: 0.737200
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.4074 Validation Accuracy: 0.721600
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.3667 Validation Accuracy: 0.729400
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.3920 Validation Accuracy: 0.709800
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.3271 Validation Accuracy: 0.722600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.3620 Validation Accuracy: 0.730400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.4038 Validation Accuracy: 0.717000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.3726 Validation Accuracy: 0.721400
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.3941 Validation Accuracy: 0.709600
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.3190 Validation Accuracy: 0.726200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.3468 Validation Accuracy: 0.734200
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.3970 Validation Accuracy: 0.722000
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.3655 Validation Accuracy: 0.722000
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.3647 Validation Accuracy: 0.718200
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.3225 Validation Accuracy: 0.721000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.3441 Validation Accuracy: 0.737400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.3725 Validation Accuracy: 0.722000
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.3445 Validation Accuracy: 0.729400
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.3494 Validation Accuracy: 0.725000
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.3189 Validation Accuracy: 0.720200
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.3344 Validation Accuracy: 0.736600
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.3905 Validation Accuracy: 0.717600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.3424 Validation Accuracy: 0.730000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.3413 Validation Accuracy: 0.726200
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.3056 Validation Accuracy: 0.724400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.3191 Validation Accuracy: 0.739800
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.3596 Validation Accuracy: 0.724000
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.3171 Validation Accuracy: 0.734400
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.3383 Validation Accuracy: 0.721800
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.2940 Validation Accuracy: 0.722200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.3150 Validation Accuracy: 0.742600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.3473 Validation Accuracy: 0.724600
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.3141 Validation Accuracy: 0.727200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.3213 Validation Accuracy: 0.725600
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.2786 Validation Accuracy: 0.729400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.3017 Validation Accuracy: 0.743600
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.3513 Validation Accuracy: 0.716000
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.3073 Validation Accuracy: 0.732600
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.3163 Validation Accuracy: 0.728800
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.2755 Validation Accuracy: 0.727000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.2901 Validation Accuracy: 0.741000
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.3254 Validation Accuracy: 0.730200
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.3109 Validation Accuracy: 0.729000
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.3128 Validation Accuracy: 0.731000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.2740 Validation Accuracy: 0.725400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.2892 Validation Accuracy: 0.739400
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.3234 Validation Accuracy: 0.724200
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.2906 Validation Accuracy: 0.735800
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.2975 Validation Accuracy: 0.730000
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.2636 Validation Accuracy: 0.727000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.2803 Validation Accuracy: 0.737600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.3047 Validation Accuracy: 0.727400
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.2764 Validation Accuracy: 0.734400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.2888 Validation Accuracy: 0.725600
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.2664 Validation Accuracy: 0.719200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.2818 Validation Accuracy: 0.736000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.3199 Validation Accuracy: 0.724800
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.2754 Validation Accuracy: 0.732000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.2812 Validation Accuracy: 0.733800
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.2648 Validation Accuracy: 0.716400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.2853 Validation Accuracy: 0.732400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.2952 Validation Accuracy: 0.725400
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.2992 Validation Accuracy: 0.722800
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.3001 Validation Accuracy: 0.724400
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.2679 Validation Accuracy: 0.722600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.2880 Validation Accuracy: 0.727000
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.2908 Validation Accuracy: 0.727400
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.2676 Validation Accuracy: 0.728800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.2820 Validation Accuracy: 0.727200
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.2717 Validation Accuracy: 0.715000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.2878 Validation Accuracy: 0.728600
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.2785 Validation Accuracy: 0.732600
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.2708 Validation Accuracy: 0.729800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.2760 Validation Accuracy: 0.737000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.2418 Validation Accuracy: 0.720800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.2558 Validation Accuracy: 0.739800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.2755 Validation Accuracy: 0.727200
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.2539 Validation Accuracy: 0.733400
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.2738 Validation Accuracy: 0.726600
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.2449 Validation Accuracy: 0.720800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.2556 Validation Accuracy: 0.738200
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.2668 Validation Accuracy: 0.732400
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.2419 Validation Accuracy: 0.739200
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.2385 Validation Accuracy: 0.736000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.2410 Validation Accuracy: 0.722000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.2570 Validation Accuracy: 0.733200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.2438 Validation Accuracy: 0.732000
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.2480 Validation Accuracy: 0.733200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.2346 Validation Accuracy: 0.735000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.2440 Validation Accuracy: 0.713800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.2365 Validation Accuracy: 0.740400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.2476 Validation Accuracy: 0.730200
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.2472 Validation Accuracy: 0.734000
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.2355 Validation Accuracy: 0.737000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.2341 Validation Accuracy: 0.714400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.2305 Validation Accuracy: 0.738400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.2506 Validation Accuracy: 0.730400
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.2169 Validation Accuracy: 0.737200
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.2343 Validation Accuracy: 0.724800
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.2355 Validation Accuracy: 0.714200
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.2375 Validation Accuracy: 0.735000
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.2393 Validation Accuracy: 0.735400
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.2142 Validation Accuracy: 0.734600
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.2230 Validation Accuracy: 0.734000
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.2128 Validation Accuracy: 0.726000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.2148 Validation Accuracy: 0.743200
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.2312 Validation Accuracy: 0.733400
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.2130 Validation Accuracy: 0.731200
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.2155 Validation Accuracy: 0.739600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.1970 Validation Accuracy: 0.724000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.2100 Validation Accuracy: 0.740400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.2167 Validation Accuracy: 0.735600
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.2227 Validation Accuracy: 0.730400
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.2244 Validation Accuracy: 0.734200
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.1998 Validation Accuracy: 0.726800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.2087 Validation Accuracy: 0.734800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.2230 Validation Accuracy: 0.732200
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.2120 Validation Accuracy: 0.729200
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.2420 Validation Accuracy: 0.723200
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.2221 Validation Accuracy: 0.718600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.2177 Validation Accuracy: 0.731400
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.2221 Validation Accuracy: 0.727200
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.2131 Validation Accuracy: 0.732400
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.2068 Validation Accuracy: 0.735200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.1876 Validation Accuracy: 0.725800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.2051 Validation Accuracy: 0.733200
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.1938 Validation Accuracy: 0.735800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.2084 Validation Accuracy: 0.734800
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.2071 Validation Accuracy: 0.734400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.2063 Validation Accuracy: 0.716800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.1995 Validation Accuracy: 0.738600
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.1999 Validation Accuracy: 0.735800
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.2161 Validation Accuracy: 0.731400
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.1960 Validation Accuracy: 0.729400
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.2076 Validation Accuracy: 0.719400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.1897 Validation Accuracy: 0.737600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.2078 Validation Accuracy: 0.731000
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.2090 Validation Accuracy: 0.728800
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.1943 Validation Accuracy: 0.738400
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.1800 Validation Accuracy: 0.727400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.1775 Validation Accuracy: 0.740000
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.1857 Validation Accuracy: 0.734000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.1836 Validation Accuracy: 0.735400
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.1774 Validation Accuracy: 0.739200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.1737 Validation Accuracy: 0.730400
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.1838 Validation Accuracy: 0.736600
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.1842 Validation Accuracy: 0.735200
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.1806 Validation Accuracy: 0.738200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.1717 Validation Accuracy: 0.740400
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.1607 Validation Accuracy: 0.731000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.1792 Validation Accuracy: 0.739000
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.1767 Validation Accuracy: 0.735600
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.1750 Validation Accuracy: 0.736000
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.1668 Validation Accuracy: 0.742400
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.1645 Validation Accuracy: 0.733000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.1640 Validation Accuracy: 0.743600
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.1657 Validation Accuracy: 0.738400
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.1736 Validation Accuracy: 0.734600
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.1618 Validation Accuracy: 0.737600
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.1505 Validation Accuracy: 0.736400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.1773 Validation Accuracy: 0.734600
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.1664 Validation Accuracy: 0.734400
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.1668 Validation Accuracy: 0.736200
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.1578 Validation Accuracy: 0.745800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.1498 Validation Accuracy: 0.735000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.1627 Validation Accuracy: 0.736400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.1497 Validation Accuracy: 0.740400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.1496 Validation Accuracy: 0.738200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.1559 Validation Accuracy: 0.738000
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.1490 Validation Accuracy: 0.732400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.1569 Validation Accuracy: 0.738400
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.1546 Validation Accuracy: 0.739400
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.1616 Validation Accuracy: 0.732600
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.1551 Validation Accuracy: 0.736800
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.1531 Validation Accuracy: 0.734200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.1587 Validation Accuracy: 0.738200
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.1511 Validation Accuracy: 0.733200
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.1613 Validation Accuracy: 0.727400
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.1615 Validation Accuracy: 0.736800
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.1371 Validation Accuracy: 0.738400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.1524 Validation Accuracy: 0.742400
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.1483 Validation Accuracy: 0.735600
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.1414 Validation Accuracy: 0.741600
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.1505 Validation Accuracy: 0.728600
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.1415 Validation Accuracy: 0.730800
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.1531 Validation Accuracy: 0.737200
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.1516 Validation Accuracy: 0.733800
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.1491 Validation Accuracy: 0.739400
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.1528 Validation Accuracy: 0.726200
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.1646 Validation Accuracy: 0.720000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.1845 Validation Accuracy: 0.722000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.1511 Validation Accuracy: 0.732600
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.1599 Validation Accuracy: 0.722800
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.1534 Validation Accuracy: 0.724400
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.1492 Validation Accuracy: 0.723600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.1584 Validation Accuracy: 0.720400
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.1417 Validation Accuracy: 0.729600
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.1357 Validation Accuracy: 0.734400
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.1498 Validation Accuracy: 0.719800
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.1616 Validation Accuracy: 0.721800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7199637293815613

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
