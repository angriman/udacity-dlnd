# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from random import random
from collections import Counter

freq_dic = {}
t = 1e-5
total_count = len(int_words)
word_count = Counter(int_words)
freq_dic = {word: count/total_count for word, count in word_count.items()}
prob_dic = {word: 1 - np.sqrt(t/freq_dic[word]) for word in word_count}
train_words = [word for word in int_words if 1 - prob_dic[word] > random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    number_of_words = np.random.randint(1, window_size+1)
    from_i = max(0, idx - number_of_words)
    to_i = min(idx + number_of_words, len(words) - 1)
    window = set(words[from_i:to_i])

    return list(window)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6245 0.1028 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.4910 0.1008 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3380 0.1016 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3813 0.1005 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2675 0.1015 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2540 0.1015 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2110 0.1011 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1877 0.1011 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1194 0.1005 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1092 0.1013 sec/batch
# Nearest to more: gerson, devises, carps, canticles, quartermaster, vdl, ytv, emoticon,
# Nearest to while: lomax, just, hogan, directory, hurled, impairing, ndp, morales,
# Nearest to zero: populism, priming, psilocybin, adamantium, lamarckism, mob, stubby, vicugna,
# Nearest to an: deut, munda, separable, paradiso, tocantins, logrus, khoisan, knob,
# Nearest to at: ashoka, fac, transitory, centimes, tendency, edirne, rathdown, bundeswehr,
# Nearest to who: pongo, retinal, topsy, daemon, stereotypes, brass, fleeting, cce,
# Nearest to eight: traditionalism, cooke, yamuna, stockhausen, ekam, accountants, ancestral, tallapoosa,
# Nearest to is: grilled, olde, unfortunately, thermos, ossetia, mutual, victim, falsificationism,
# Nearest to operations: sixtus, unleash, generalizes, aeneid, abductions, wettin, ogpu, producers,
# Nearest to smith: gophers, decks, paycheck, intermittent, jmu, bhumi, fakir, downey,
# Nearest to stage: cooley, prisoner, engaged, fraternal, voraciously, miyamoto, srpska, libration,
# Nearest to pope: characterised, coached, shuja, gump, miyamoto, birka, battered, ema,
# Nearest to applied: ga, myelinated, razi, critically, pathogens, galician, concerted, phraseology,
# Nearest to engineering: mentioned, federko, narbonne, evaluations, roos, fulk, loyalists, variance,
# Nearest to bill: congruent, booker, terminals, malabar, benevento, methyl, congregation, colophon,
# Nearest to cost: andrey, frankenchrist, dotted, ayrton, oncoming, ferns, ptb, federally,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1021 0.1023 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0371 0.1015 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0131 0.1009 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9326 0.1014 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8742 0.1009 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8363 0.1015 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7845 0.1016 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7864 0.1019 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7121 0.1015 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7166 0.1016 sec/batch
# Nearest to more: gerson, pool, potentially, expect, resignation, carps, recommended, noted,
# Nearest to while: just, directory, lomax, morales, hurled, capitulation, superior, required,
# Nearest to zero: division, psilocybin, ballantine, adamantium, populism, detail, priming, mob,
# Nearest to an: tocantins, khoisan, process, winner, separable, darker, refers, describe,
# Nearest to at: tendency, ashoka, fac, bnetd, wider, further, zone, german,
# Nearest to who: retinal, daemon, modern, topsy, brass, tragic, fleeting, pongo,
# Nearest to eight: traditionalism, cooke, ancestral, yamuna, basement, whip, ekam, distinction,
# Nearest to is: mutual, unfortunately, victim, material, governor, keyboard, grilled, achieve,
# Nearest to operations: herman, producers, generalizes, aeneid, sledges, complexion, cults, msa,
# Nearest to smith: gophers, decks, intermittent, jmu, clothes, paycheck, downey, fakir,
# Nearest to stage: engaged, cooley, prisoner, december, fraternal, voraciously, critics, worthy,
# Nearest to pope: characterised, coached, battered, miyamoto, gump, trough, jim, shuja,
# Nearest to applied: critically, pathogens, myelinated, example, evident, eukaryote, concerted, ga,
# Nearest to engineering: mentioned, federko, predetermined, evaluations, jettison, cheaper, prescient, spent,
# Nearest to bill: terminals, congruent, booker, congregation, methyl, malabar, gut, plume,
# Nearest to cost: dotted, andrey, oncoming, see, ayrton, longer, frankenchrist, ferns,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6380 0.1027 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6065 0.1017 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.5794 0.1025 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.5525 0.1016 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.4997 0.1021 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5078 0.1028 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.4917 0.1019 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.4728 0.1025 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.4756 0.1024 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.4375 0.1020 sec/batch
# Nearest to more: gerson, pool, ytv, carps, sch, potentially, recommended, expect,
# Nearest to while: just, lomax, directory, capitulation, morales, hobbyists, hurled, hogan,
# Nearest to zero: ballantine, one, detail, mob, populism, falklands, psilocybin, adamantium,
# Nearest to an: separable, spin, tocantins, khoisan, winner, darker, refers, dishes,
# Nearest to at: fac, tendency, ashoka, transitory, german, impacts, centimes, bnetd,
# Nearest to who: topsy, daemon, stereotypes, retinal, brass, earning, sarcophagus, modern,
# Nearest to eight: traditionalism, cooke, whip, basement, ekam, stockhausen, republicans, physicist,
# Nearest to is: unfortunately, victim, mutual, governor, grilled, material, votes, achieve,
# Nearest to operations: producers, herman, generalizes, cults, grew, aeneid, powered, complexion,
# Nearest to smith: gophers, decks, intermittent, jmu, clothes, lesbian, downey, unhelpful,
# Nearest to stage: engaged, cooley, prisoner, fraternal, voraciously, kpd, regicides, boyle,
# Nearest to pope: characterised, coached, reprint, jim, battered, miyamoto, ce, trough,
# Nearest to applied: critically, evident, pathogens, ga, myelinated, galician, immense, concerted,
# Nearest to engineering: mentioned, federko, predetermined, evaluations, cheaper, current, edgard, requested,
# Nearest to bill: terminals, congregation, booker, congruent, garnered, methyl, gut, medal,
# Nearest to cost: dotted, oncoming, andrey, ferns, frankenchrist, ayrton, twinned, see,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.4586 0.1033 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.4208 0.1026 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4070 0.1020 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.3963 0.1018 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4301 0.1025 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.3684 0.1022 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.3833 0.1025 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4308 0.1023 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.3859 0.1025 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3358 0.1017 sec/batch
# Nearest to more: gerson, pool, ytv, expect, carps, emoticon, sch, devises,
# Nearest to while: just, hogan, lomax, morales, capitulation, gazette, shipyards, calcio,
# Nearest to zero: ballantine, one, populism, falklands, alva, psilocybin, mob, treaty,
# Nearest to an: separable, spin, tocantins, deut, perpendicular, dishes, refers, ckel,
# Nearest to at: fac, ashoka, crowding, tendency, transitory, freeze, bnetd, rathdown,
# Nearest to who: daemon, topsy, stereotypes, earning, sarcophagus, brass, retinal, motto,
# Nearest to eight: physicist, cooke, nine, four, basement, whip, traditionalism, politician,
# Nearest to is: unfortunately, grilled, hounds, mathbb, thermos, ossetia, victim, escalation,
# Nearest to operations: generalizes, producers, complexion, herman, fatimids, aeneid, unleash, cults,
# Nearest to smith: gophers, decks, jmu, intermittent, clothes, lesbian, downey, unilateral,
# Nearest to stage: cooley, engaged, prisoner, fraternal, boyle, voraciously, regicides, snowflake,
# Nearest to pope: characterised, coached, birka, battered, reprint, thy, nephews, jim,
# Nearest to applied: pathogens, ga, critically, evident, myelinated, fireworks, galician, identity,
# Nearest to engineering: mentioned, federko, evaluations, predetermined, cheaper, current, jettison, variance,
# Nearest to bill: terminals, booker, congruent, congregation, garnered, malabar, gut, methyl,
# Nearest to cost: dotted, oncoming, andrey, ferns, frankenchrist, air, ayrton, federally,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3579 0.1034 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.3488 0.1020 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.2777 0.1026 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.2940 0.1027 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3186 0.1024 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.3236 0.1025 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.2887 0.0751 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.2546 0.1026 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.2254 0.1027 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.1875 0.1029 sec/batch
# Nearest to more: gerson, ytv, pool, devises, satisfies, carps, vdl, canticles,
# Nearest to while: hogan, just, lomax, capitulation, impairing, calcio, reliever, morales,
# Nearest to zero: ballantine, one, falklands, alva, populism, psilocybin, boathouse, yardbirds,
# Nearest to an: separable, deut, tocantins, spin, singlet, perpendicular, khoisan, connolly,
# Nearest to at: ashoka, transitory, crowding, fac, tendency, rathdown, edirne, freeze,
# Nearest to who: topsy, daemon, sarcophagus, stereotypes, earning, renaud, pongo, hermits,
# Nearest to eight: physicist, nine, politician, four, fran, basement, earl, stockhausen,
# Nearest to is: unfortunately, grilled, hounds, sahelian, escalation, emitting, mathbb, ossetia,
# Nearest to operations: generalizes, complexion, fatimids, sixtus, powered, writs, cults, cartoonists,
# Nearest to smith: gophers, decks, jmu, intermittent, downey, clothes, lesbian, governor,
# Nearest to stage: cooley, engaged, prisoner, fraternal, regicides, gaylord, srpska, boyle,
# Nearest to pope: birka, nephews, reprint, patriarch, christians, jim, miyamoto, thy,
# Nearest to applied: pathogens, myelinated, ga, evident, galician, critically, identity, fireworks,
# Nearest to engineering: federko, mentioned, evaluations, cheaper, variance, current, loyalists, jettison,
# Nearest to bill: terminals, booker, congruent, garnered, malabar, congregation, taylor, fathering,
# Nearest to cost: dotted, oncoming, andrey, ferns, frankenchrist, federally, bulk, pragmatist,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.2197 0.1042 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.1852 0.1025 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.1339 0.1029 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.2109 0.1025 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.1867 0.1025 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.1589 0.1029 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.1429 0.1032 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.0919 0.1024 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.1102 0.1025 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.1024 0.1025 sec/batch
# Nearest to more: gerson, ytv, pool, cronquist, carps, satisfies, shape, vdl,
# Nearest to while: lomax, just, hogan, capitulation, impairing, deterrent, underneath, ndp,
# Nearest to zero: falklands, ballantine, populism, one, four, psilocybin, three, total,
# Nearest to an: separable, perpendicular, deut, spin, singlet, khoisan, ckel, connolly,
# Nearest to at: transitory, crowding, ashoka, tendency, edirne, fac, hillbilly, rathdown,
# Nearest to who: topsy, sarcophagus, daemon, renaud, hermits, pongo, stereotypes, decolonisation,
# Nearest to eight: stockhausen, basement, four, cooke, pearson, konoe, yao, doyle,
# Nearest to is: grilled, sahelian, escalation, hounds, leaching, unfortunately, emitting, frac,
# Nearest to operations: generalizes, complexion, powered, ogpu, compiling, paigc, fatimids, lone,
# Nearest to smith: gophers, decks, jmu, downey, intermittent, lesbian, clothes, paycheck,
# Nearest to stage: cooley, srpska, engaged, nationalrat, prisoner, fraternal, splices, libration,
# Nearest to pope: patriarch, birka, christians, benedict, nephews, thy, miyamoto, coached,
# Nearest to applied: pathogens, myelinated, evident, example, hose, galician, ga, razi,
# Nearest to engineering: evaluations, current, cheaper, federko, biomedical, marketable, loyalists, variance,
# Nearest to bill: booker, congregation, taylor, congruent, terminals, garnered, carr, malabar,
# Nearest to cost: dotted, oncoming, bulk, andrey, frankenchrist, pragmatist, air, ferns,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.1271 0.1040 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.1100 0.1032 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.0933 0.1040 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.1164 0.1025 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.0979 0.1026 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.1187 0.1024 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0687 0.1031 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.0685 0.1020 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.1212 0.1027 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.0493 0.1030 sec/batch
# Nearest to more: gerson, vdl, pool, ytv, cronquist, canticles, shape, devises,
# Nearest to while: lomax, hogan, just, everquest, impairing, capitulation, educates, deterrent,
# Nearest to zero: four, ballantine, three, one, falklands, populism, psilocybin, two,
# Nearest to an: separable, deut, spin, singlet, connolly, ckel, perpendicular, confocal,
# Nearest to at: transitory, crowding, ashoka, tendency, edirne, hillbilly, fac, lambasted,
# Nearest to who: topsy, hermits, sarcophagus, renaud, daemon, stereotypes, cowper, pongo,
# Nearest to eight: stockhausen, basement, four, bryant, pearson, cooke, doyle, physicist,
# Nearest to is: leaching, sahelian, frac, grilled, hounds, thermos, hausdorff, escalation,
# Nearest to operations: generalizes, complexion, powered, paigc, compiling, ogpu, units, extension,
# Nearest to smith: gophers, decks, downey, jmu, lesbian, lodger, clothes, paycheck,
# Nearest to stage: cooley, srpska, nationalrat, engaged, splices, prisoner, libration, kpd,
# Nearest to pope: patriarch, christians, birka, benedict, nephews, ecumenical, bishops, episcopalians,
# Nearest to applied: pathogens, identity, myelinated, hose, evident, razi, example, phraseology,
# Nearest to engineering: biomedical, evaluations, current, cheaper, marketable, federko, sinc, jettison,
# Nearest to bill: taylor, booker, congregation, congruent, garnered, terminals, fathering, malabar,
# Nearest to cost: dotted, bulk, oncoming, frankenchrist, ptb, andrey, pragmatist, air,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.0606 0.1036 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0782 0.1020 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.0581 0.1029 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.0228 0.1017 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.0846 0.1026 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.0633 0.1032 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0919 0.1027 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.0550 0.1031 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.0156 0.1028 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.0149 0.1024 sec/batch
# Nearest to more: pool, gerson, devises, ytv, vdl, cronquist, canticles, shape,
# Nearest to while: lomax, impairing, everquest, capitulation, hogan, educates, just, ndp,
# Nearest to zero: three, four, ballantine, falklands, two, populism, one, akshara,
# Nearest to an: separable, deut, connolly, singlet, linkin, ckel, spin, chauffeur,
# Nearest to at: transitory, crowding, tendency, ashoka, hillbilly, rathdown, edirne, lambasted,
# Nearest to who: topsy, hermits, daemon, sarcophagus, renaud, fpss, stereotypes, decolonisation,
# Nearest to eight: stockhausen, basement, four, bryant, presbyterianism, pearson, publishing, evgeny,
# Nearest to is: leaching, hounds, grilled, sweeter, sahelian, hausdorff, arched, batavians,
# Nearest to operations: generalizes, ogpu, paigc, compiling, powered, complexion, units, acronym,
# Nearest to smith: gophers, decks, downey, lesbian, jmu, lodger, paycheck, clothes,
# Nearest to stage: cooley, srpska, nationalrat, splices, libration, kpd, barkley, engaged,
# Nearest to pope: patriarch, benedict, christians, birka, ecumenical, nephews, bishops, thy,
# Nearest to applied: pathogens, identity, evident, hose, myelinated, razi, example, phraseology,
# Nearest to engineering: biomedical, evaluations, current, marketable, cheaper, federko, sinc, jettison,
# Nearest to bill: taylor, booker, garnered, fathering, congregation, congruent, sybil, terminals,
# Nearest to cost: dotted, bulk, oncoming, ptb, frankenchrist, air, ferns, andrey,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.0253 0.1055 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9828 0.1033 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0861 0.1028 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0729 0.1033 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.0609 0.1029 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.9586 0.1023 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.9952 0.1015 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.0271 0.1019 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.9420 0.1035 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 3.9972 0.1023 sec/batch
# Nearest to more: devises, ytv, pool, gerson, vdl, canticles, nanoscale, cronquist,
# Nearest to while: hogan, impairing, lomax, everquest, ndp, just, educates, nothingness,
# Nearest to zero: four, three, two, ballantine, runways, falklands, one, populism,
# Nearest to an: separable, connolly, singlet, deut, linkin, ckel, hauptmann, geller,
# Nearest to at: transitory, crowding, tendency, hillbilly, ashoka, rathdown, edirne, lambasted,
# Nearest to who: topsy, hermits, daemon, renaud, decolonisation, sarcophagus, fpss, stereotypes,
# Nearest to eight: four, stockhausen, basement, evgeny, bryant, physicist, ballantine, nine,
# Nearest to is: leaching, hounds, sweeter, batavians, grilled, escalation, hausdorff, sahelian,
# Nearest to operations: generalizes, ogpu, compiling, paigc, powered, ugarte, units, aberrations,
# Nearest to smith: gophers, decks, downey, lesbian, lodger, jmu, paycheck, mormon,
# Nearest to stage: cooley, srpska, nationalrat, libration, barkley, splices, regicides, biggest,
# Nearest to pope: patriarch, benedict, christians, nephews, ecumenical, birka, bishops, episcopalians,
# Nearest to applied: pathogens, hose, myelinated, evident, identity, razi, benzoyl, phraseology,
# Nearest to engineering: biomedical, marketable, current, cheaper, evaluations, federko, sinc, jettison,
# Nearest to bill: booker, garnered, taylor, fathering, sybil, congruent, congregation, terminals,
# Nearest to cost: dotted, bulk, oncoming, ptb, costs, frankenchrist, ferns, reasonable,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 3.9733 0.1037 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 3.9855 0.1029 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.0270 0.0475 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9506 0.1023 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.9285 0.1027 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.9455 0.1033 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.9205 0.1022 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.8925 0.1038 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.9297 0.1030 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.8858 0.1028 sec/batch
# Nearest to more: vdl, devises, ytv, pool, gerson, canticles, nanoscale, cronquist,
# Nearest to while: impairing, mitte, nothingness, lomax, educates, everquest, deterrent, hogan,
# Nearest to zero: three, four, two, ballantine, runways, falklands, gini, populism,
# Nearest to an: singlet, connolly, linkin, separable, deut, ckel, perpendicular, geller,
# Nearest to at: transitory, crowding, tendency, lambasted, hillbilly, rathdown, edirne, ashoka,
# Nearest to who: topsy, hermits, renaud, sarcophagus, daemon, decolonisation, pongo, cowper,
# Nearest to eight: stockhausen, four, evgeny, basement, bryant, yao, doyle, mhz,
# Nearest to is: leaching, batavians, sweeter, grilled, escalation, sahelian, hausdorff, hounds,
# Nearest to operations: generalizes, ogpu, compiling, paigc, powered, acronym, tamm, ugarte,
# Nearest to smith: gophers, decks, downey, lesbian, jmu, paycheck, lodger, mormon,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, harp, kpd, deja,
# Nearest to pope: patriarch, benedict, birka, thy, ecumenical, bishops, christians, nephews,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, evident, identity, phraseology, razi,
# Nearest to engineering: biomedical, marketable, current, cheaper, evaluations, federko, matador, sinc,
# Nearest to bill: booker, garnered, fathering, taylor, sybil, terminals, congregation, plume,
# Nearest to cost: dotted, bulk, ptb, oncoming, costs, abl, frankenchrist, reasonable,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.9455 0.1035 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.9230 0.1031 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.9118 0.1024 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.8306 0.1027 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.8684 0.1028 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.8663 0.1026 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.8491 0.1026 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8731 0.1029 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.9006 0.1033 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.8638 0.1023 sec/batch
# Nearest to more: vdl, ytv, devises, pool, canticles, gerson, drying, nanoscale,
# Nearest to while: mitte, impairing, educates, everquest, lomax, hogan, deterrent, nothingness,
# Nearest to zero: three, four, ballantine, gini, populism, two, falklands, heliports,
# Nearest to an: singlet, linkin, deut, connolly, separable, geller, ckel, spin,
# Nearest to at: crowding, transitory, lambasted, tendency, impacts, edirne, hillbilly, rathdown,
# Nearest to who: topsy, hermits, decolonisation, renaud, daemon, pongo, cowper, sarcophagus,
# Nearest to eight: stockhausen, four, bryant, evgeny, basement, sebald, yao, pearson,
# Nearest to is: leaching, sweeter, batavians, hausdorff, grilled, sahelian, escalation, hounds,
# Nearest to operations: generalizes, ogpu, paigc, compiling, powered, units, tamm, brute,
# Nearest to smith: gophers, downey, decks, lesbian, jmu, paycheck, lodger, mormon,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, gaylord, kpd, barkley,
# Nearest to pope: patriarch, benedict, thy, alexandria, bishops, christians, birka, ecumenical,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, razi, eukaryote, odometer, evident,
# Nearest to engineering: biomedical, marketable, matador, current, agricultural, federko, evaluations, cheaper,
# Nearest to bill: booker, garnered, fathering, taylor, sybil, plume, congregation, terminals,
# Nearest to cost: dotted, bulk, ptb, oncoming, costs, abl, andrey, frankenchrist,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.8742 0.1044 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.9307 0.1032 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.8563 0.1026 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.8170 0.1026 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8773 0.1024 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.8734 0.1024 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8893 0.1029 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.8334 0.1019 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.8382 0.1032 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8692 0.1022 sec/batch
# Nearest to more: ytv, devises, vdl, canticles, pool, nanoscale, holism, cronquist,
# Nearest to while: mitte, impairing, hurled, educates, everquest, guyane, hogan, reliever,
# Nearest to zero: three, four, two, gini, ballantine, populism, heliports, yzerman,
# Nearest to an: connolly, singlet, ckel, linkin, deut, separable, homology, hauptmann,
# Nearest to at: transitory, crowding, tendency, lambasted, ashoka, kombinate, edirne, hillbilly,
# Nearest to who: topsy, hermits, decolonisation, cowper, pongo, daemon, fpss, symptomatology,
# Nearest to eight: stockhausen, evgeny, bryant, four, presbyterianism, histoire, basement, melchior,
# Nearest to is: leaching, sweeter, batavians, hausdorff, sahelian, grilled, escalation, propane,
# Nearest to operations: generalizes, ogpu, compiling, powered, paigc, tamm, brute, acronym,
# Nearest to smith: gophers, downey, lesbian, decks, jmu, lodger, paycheck, mormon,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, harp, kpd, regicides,
# Nearest to pope: patriarch, benedict, bishops, thy, khayy, ecumenical, birka, mehmed,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, odometer, gangsta, eukaryote, razi,
# Nearest to engineering: biomedical, marketable, matador, current, evaluations, federko, academic, cheaper,
# Nearest to bill: booker, garnered, taylor, fathering, congregation, plume, terminals, rumsfeld,
# Nearest to cost: dotted, costs, ptb, bulk, oncoming, abl, jacoby, frankenchrist,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8798 0.1031 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8573 0.1036 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8938 0.1022 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8748 0.1025 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.8388 0.1027 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.8155 0.1027 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.8546 0.1021 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.8171 0.1033 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8801 0.1031 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.9100 0.1027 sec/batch
# Nearest to more: ytv, vdl, canticles, devises, pool, nanoscale, niklas, holism,
# Nearest to while: mitte, impairing, morales, hurled, hogan, guyane, reliever, educates,
# Nearest to zero: three, four, populism, ballantine, two, yzerman, winthrop, falklands,
# Nearest to an: linkin, connolly, allman, singlet, deut, ckel, geller, hauptmann,
# Nearest to at: lambasted, transitory, crowding, tendency, ashoka, hillbilly, saladin, kombinate,
# Nearest to who: topsy, hermits, decolonisation, cowper, renaud, daemon, peterborough, stereotypes,
# Nearest to eight: stockhausen, evgeny, bryant, four, histoire, yao, presbyterianism, konoe,
# Nearest to is: leaching, sweeter, batavians, escalation, hausdorff, dissenters, jacobus, sahelian,
# Nearest to operations: generalizes, ogpu, paigc, compiling, federative, brute, acronym, suborbital,
# Nearest to smith: gophers, downey, lesbian, decks, paycheck, jmu, mormon, lodger,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, harp, gaylord, kpd,
# Nearest to pope: patriarch, benedict, nephews, mehmed, bishops, flavius, khayy, pius,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, razi, odometer, gangsta, phraseology,
# Nearest to engineering: biomedical, marketable, matador, federko, academic, evaluations, current, cheaper,
# Nearest to bill: booker, garnered, fathering, rumsfeld, congregation, terminals, taylor, icj,
# Nearest to cost: costs, dotted, ptb, abl, bulk, oncoming, andrey, frankenchrist,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.9180 0.1037 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.8262 0.1028 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.8120 0.1015 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.8508 0.1025 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.7112 0.1025 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.8146 0.1024 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.8475 0.1021 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.8119 0.1031 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8645 0.0196 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.8021 0.1027 sec/batch
# Nearest to more: ytv, vdl, devises, canticles, pool, holism, nanoscale, niklas,
# Nearest to while: mitte, impairing, hogan, guyane, reliever, snowdon, morales, hurled,
# Nearest to zero: three, four, two, populism, yzerman, ballantine, gini, mmm,
# Nearest to an: linkin, connolly, allman, singlet, deut, ckel, karst, officer,
# Nearest to at: lambasted, crowding, transitory, diligent, tendency, hillbilly, noteworthy, saladin,
# Nearest to who: topsy, decolonisation, hermits, cowper, peterborough, pongo, daemon, renaud,
# Nearest to eight: stockhausen, evgeny, bryant, four, yao, pearson, konoe, histoire,
# Nearest to is: leaching, sweeter, batavians, hausdorff, sahelian, escalation, propane, grouping,
# Nearest to operations: generalizes, ogpu, compiling, paigc, brute, federative, divisor, extension,
# Nearest to smith: gophers, downey, lesbian, decks, paycheck, mormon, jmu, lodger,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, harp, audition, inquisitive,
# Nearest to pope: benedict, patriarch, nephews, mehmed, khayy, bishops, flavius, papal,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, odometer, kam, gangsta, phraseology,
# Nearest to engineering: biomedical, marketable, matador, agricultural, academic, evaluations, federko, current,
# Nearest to bill: booker, garnered, rumsfeld, fathering, taylor, terminals, congregation, carr,
# Nearest to cost: ptb, costs, dotted, abl, oncoming, bulk, frankenchrist, visibly,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7765 0.1047 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7759 0.1038 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.7864 0.1030 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.7690 0.1027 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.7900 0.1031 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.7258 0.1024 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7865 0.1024 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.7643 0.1023 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.8207 0.1025 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.7312 0.1027 sec/batch
# Nearest to more: ytv, vdl, canticles, devises, pool, holism, niklas, nanoscale,
# Nearest to while: mitte, impairing, guyane, reliever, morales, hurled, hogan, goaltender,
# Nearest to zero: three, populism, yzerman, four, accessed, gini, two, mmm,
# Nearest to an: linkin, singlet, connolly, allman, officer, geller, karst, separable,
# Nearest to at: crowding, lambasted, tendency, transitory, diligent, ashoka, noteworthy, hillbilly,
# Nearest to who: decolonisation, hermits, topsy, pongo, daemon, cowper, renaud, peterborough,
# Nearest to eight: stockhausen, evgeny, bryant, yao, four, konoe, mhz, gmelin,
# Nearest to is: leaching, sweeter, batavians, grouping, escalation, repertory, lanka, propane,
# Nearest to operations: generalizes, ogpu, brute, paigc, compiling, federative, divisor, paddock,
# Nearest to smith: gophers, lesbian, downey, mormon, paycheck, decks, jmu, lodger,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, audition, harp, sing,
# Nearest to pope: benedict, patriarch, bishops, xi, keltoi, mehmed, thy, viii,
# Nearest to applied: pathogens, benzoyl, hose, odometer, myelinated, kam, gangsta, razi,
# Nearest to engineering: biomedical, agricultural, marketable, matador, evaluations, academic, cheaper, federko,
# Nearest to bill: garnered, booker, congregation, fathering, rumsfeld, carr, terminals, handlers,
# Nearest to cost: costs, abl, dotted, bulk, ptb, oncoming, jacoby, andrey,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.6999 0.1046 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.7239 0.1030 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.6973 0.1024 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.7455 0.1023 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7628 0.1024 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.7460 0.1023 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7436 0.1029 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7655 0.1022 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.7435 0.1030 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.7217 0.1024 sec/batch
# Nearest to more: ytv, vdl, canticles, pool, devises, holism, niklas, nanoscale,
# Nearest to while: mitte, impairing, guyane, hurled, reliever, morales, hogan, educates,
# Nearest to zero: populism, three, yzerman, two, ballantine, accessed, mmm, four,
# Nearest to an: linkin, singlet, connolly, homology, issuing, separable, rim, karst,
# Nearest to at: lambasted, crowding, transitory, ashoka, tendency, diligent, saladin, centimes,
# Nearest to who: hermits, decolonisation, topsy, peterborough, cowper, daemon, renaud, dolmen,
# Nearest to eight: evgeny, stockhausen, bryant, four, melchior, yao, ballantine, konoe,
# Nearest to is: leaching, sweeter, frac, hausdorff, propane, batavians, diffeomorphism, denominators,
# Nearest to operations: generalizes, ogpu, brute, paigc, federative, compiling, divisor, paddock,
# Nearest to smith: gophers, downey, lesbian, mormon, paycheck, decks, jmu, conger,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, sing, audition, harp,
# Nearest to pope: benedict, patriarch, papal, keltoi, bishops, papacy, mehmed, pius,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, odometer, kam, extrinsic, gangsta,
# Nearest to engineering: biomedical, agricultural, marketable, academic, matador, evaluations, postgraduate, universities,
# Nearest to bill: booker, garnered, congregation, rumsfeld, fathering, handlers, taylor, terminals,
# Nearest to cost: costs, abl, ptb, oncoming, jacoby, bulk, dotted, andrey,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.7657 0.1038 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7552 0.1022 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.7917 0.1028 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.7652 0.1013 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.7405 0.1024 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.7233 0.1020 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7718 0.1021 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.7431 0.1030 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7687 0.1025 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7351 0.1033 sec/batch
# Nearest to more: ytv, vdl, niklas, canticles, nanoscale, pool, holism, devises,
# Nearest to while: mitte, impairing, morales, hurled, reliever, hogan, guyane, raj,
# Nearest to zero: populism, three, yzerman, two, accessed, mmm, four, five,
# Nearest to an: linkin, connolly, singlet, allman, homology, hauptmann, issuing, karst,
# Nearest to at: lambasted, ashoka, transitory, crowding, saladin, diligent, tendency, edirne,
# Nearest to who: decolonisation, hermits, topsy, dolmen, daemon, peterborough, renaud, fpss,
# Nearest to eight: bryant, stockhausen, evgeny, melchior, yao, four, cromarty, gmelin,
# Nearest to is: leaching, sweeter, batavians, propane, jacobus, breakdancing, diffeomorphism, hausdorff,
# Nearest to operations: generalizes, ogpu, brute, paigc, operation, federative, armed, operational,
# Nearest to smith: gophers, downey, paycheck, lesbian, mormon, jmu, conger, lodger,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, boasting, sing, kpd,
# Nearest to pope: benedict, patriarch, papal, bishops, papacy, keltoi, schism, mehmed,
# Nearest to applied: pathogens, hose, benzoyl, myelinated, gangsta, kam, odometer, extrinsic,
# Nearest to engineering: biomedical, marketable, agricultural, matador, evaluations, postgraduate, prerequisite, federko,
# Nearest to bill: booker, congregation, garnered, fathering, handlers, rumsfeld, terminals, session,
# Nearest to cost: costs, abl, jacoby, oncoming, ptb, andrey, compensated, bulk,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.7398 0.1041 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.7183 0.1029 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.7393 0.1023 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7374 0.1031 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.7602 0.1032 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.8105 0.1026 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.8073 0.1022 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.7249 0.1029 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.7179 0.1024 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.7385 0.1015 sec/batch
# Nearest to more: ytv, vdl, devises, niklas, holism, pool, nanoscale, canticles,
# Nearest to while: mitte, impairing, morales, reliever, hurled, dependability, hogan, raj,
# Nearest to zero: three, populism, two, yzerman, mmm, estimated, gini, four,
# Nearest to an: linkin, allman, connolly, singlet, homology, issuing, hauptmann, rim,
# Nearest to at: lambasted, crowding, tendency, transitory, diligent, ashoka, saladin, griggs,
# Nearest to who: hermits, topsy, decolonisation, renaud, dolmen, peterborough, cowper, daemon,
# Nearest to eight: stockhausen, evgeny, bryant, yao, gmelin, cromarty, melchior, beac,
# Nearest to is: leaching, sweeter, batavians, jacobus, lanka, diffeomorphism, propane, frac,
# Nearest to operations: ogpu, generalizes, brute, paigc, operation, federative, armed, operational,
# Nearest to smith: gophers, downey, mormon, paycheck, lesbian, jmu, intermittent, lodger,
# Nearest to stage: cooley, srpska, nationalrat, libration, splices, boasting, sing, synth,
# Nearest to pope: benedict, patriarch, papal, mehmed, pius, bishops, keltoi, lateran,
# Nearest to applied: pathogens, benzoyl, hose, myelinated, odometer, kam, extrinsic, gangsta,
# Nearest to engineering: biomedical, matador, marketable, agricultural, postgraduate, evaluations, academic, prerequisite,
# Nearest to bill: booker, garnered, fathering, congregation, rumsfeld, handlers, ignored, torvalds,
# Nearest to cost: costs, abl, jacoby, oncoming, ptb, andrey, frankenchrist, visibly,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6728 0.1034 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.7316 0.1027 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.7321 0.1030 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.7307 0.1034 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7514 0.1025 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.7171 0.0946 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.7158 0.1036 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6798 0.1033 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.7013 0.1019 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.6675 0.1022 sec/batch
# Nearest to more: ytv, vdl, devises, niklas, nanoscale, holism, canticles, elegiac,
# Nearest to while: impairing, mitte, raj, morales, hurled, divides, dependability, reliever,
# Nearest to zero: yzerman, two, three, mmm, populism, estimated, accessed, four,
# Nearest to an: linkin, allman, connolly, singlet, rim, homology, karst, issuing,
# Nearest to at: lambasted, crowding, diligent, transitory, ashoka, saladin, edirne, tendency,
# Nearest to who: hermits, topsy, decolonisation, peterborough, daemon, dolmen, keg, fpss,
# Nearest to eight: evgeny, stockhausen, bryant, gmelin, yao, melchior, cromarty, four,
# Nearest to is: leaching, batavians, sweeter, jacobus, lanka, southwest, propane, frac,
# Nearest to operations: generalizes, ogpu, brute, federative, operation, divisor, paigc, paddock,
# Nearest to smith: gophers, downey, mormon, paycheck, conger, jmu, lodger, lesbian,
# Nearest to stage: cooley, srpska, libration, nationalrat, splices, sing, boasting, kpd,
# Nearest to pope: benedict, patriarch, mehmed, papal, pius, viii, keltoi, xi,
# Nearest to applied: pathogens, benzoyl, hose, odometer, myelinated, kam, extrinsic, gangsta,
# Nearest to engineering: biomedical, matador, agricultural, marketable, postgraduate, evaluations, academic, puget,
# Nearest to bill: booker, garnered, rumsfeld, congregation, fathering, handlers, carr, torvalds,
# Nearest to cost: costs, abl, oncoming, jacoby, ayrton, andrey, frankenchrist, ptb,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.7098 0.1039 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.6309 0.1030 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.7073 0.1016 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.6952 0.1025 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.7132 0.1021 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6893 0.1027 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.6034 0.1029 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6508 0.1027 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.6112 0.1026 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6629 0.1032 sec/batch
# Nearest to more: ytv, nanoscale, vdl, devises, holism, elegiac, niklas, drastically,
# Nearest to while: mitte, morales, impairing, divides, dependability, raj, hurled, technically,
# Nearest to zero: yzerman, three, two, populism, estimated, mmm, gini, total,
# Nearest to an: linkin, allman, singlet, homology, connolly, rim, issuing, karst,
# Nearest to at: lambasted, crowding, diligent, ashoka, saladin, transitory, tendency, noteworthy,
# Nearest to who: decolonisation, peterborough, hermits, dolmen, topsy, keg, daemon, symptomatology,
# Nearest to eight: stockhausen, yao, bryant, evgeny, cromarty, gmelin, beac, melchior,
# Nearest to is: leaching, sweeter, batavians, propane, sturmgewehr, diffeomorphism, southwest, competences,
# Nearest to operations: generalizes, brute, ogpu, divisor, operation, deployable, federative, paigc,
# Nearest to smith: gophers, downey, mormon, paycheck, lodger, conger, lesbian, jmu,
# Nearest to stage: cooley, srpska, libration, nationalrat, splices, boasting, kpd, ottonian,
# Nearest to pope: benedict, patriarch, papal, mehmed, pius, schism, papacy, viii,
# Nearest to applied: pathogens, benzoyl, hose, odometer, myelinated, nylon, extrinsic, kam,
# Nearest to engineering: biomedical, agricultural, matador, marketable, puget, postgraduate, federko, evaluations,
# Nearest to bill: booker, garnered, handlers, congregation, carr, fathering, rumsfeld, session,
# Nearest to cost: costs, abl, ayrton, visibly, oncoming, frankenchrist, compensated, ptb,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6922 0.1039 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.7026 0.1024 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.6942 0.1030 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.6951 0.1024 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.7313 0.1022 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6312 0.1023 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.7119 0.1029 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.6729 0.1027 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6797 0.1023 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6850 0.1023 sec/batch
# Nearest to more: niklas, ytv, nanoscale, elegiac, devises, holism, vdl, pool,
# Nearest to while: morales, mitte, raj, hurled, impairing, divides, technically, dependability,
# Nearest to zero: yzerman, populism, two, mmm, three, estimated, gini, accessed,
# Nearest to an: linkin, singlet, allman, connolly, homology, issuing, rim, hauptmann,
# Nearest to at: lambasted, ashoka, transitory, saladin, crowding, diligent, arrangers, noteworthy,
# Nearest to who: hermits, peterborough, daemon, keg, decolonisation, dolmen, topsy, symptomatology,
# Nearest to eight: bryant, evgeny, stockhausen, gmelin, yao, melchior, four, cromarty,
# Nearest to is: leaching, sweeter, propane, diffeomorphism, breakdancing, sturmgewehr, jacobus, repertory,
# Nearest to operations: generalizes, brute, ogpu, deployable, divisor, paigc, federative, sitcoms,
# Nearest to smith: gophers, downey, paycheck, conger, mormon, decks, lodger, inexplicably,
# Nearest to stage: cooley, srpska, libration, nationalrat, splices, boasting, synth, kpd,
# Nearest to pope: benedict, patriarch, papal, schism, pius, papacy, mehmed, lateran,
# Nearest to applied: pathogens, benzoyl, hose, odometer, nylon, myelinated, extrinsic, kam,
# Nearest to engineering: biomedical, matador, agricultural, marketable, prerequisite, postgraduate, evaluations, puget,
# Nearest to bill: booker, carr, handlers, garnered, torvalds, cullen, fathering, plume,
# Nearest to cost: costs, abl, ayrton, visibly, frankenchrist, compensated, planners, jacoby,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6773 0.1042 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6557 0.1023 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6821 0.1017 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6856 0.1026 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.7105 0.1024 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.6826 0.1025 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6631 0.1020 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.6287 0.1029 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.6617 0.1023 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.7011 0.1032 sec/batch
# Nearest to more: ytv, nanoscale, niklas, devises, elegiac, pool, microbial, vdl,
# Nearest to while: morales, raj, mitte, impairing, dependability, divides, hurled, technically,
# Nearest to zero: populism, two, yzerman, three, mmm, estimated, tachelhit, accessed,
# Nearest to an: linkin, singlet, connolly, allman, homology, issuing, rim, hauptmann,
# Nearest to at: lambasted, saladin, diligent, ashoka, transitory, arrangers, crowding, centimes,
# Nearest to who: hermits, decolonisation, peterborough, dolmen, keg, daemon, topsy, tartushi,
# Nearest to eight: bryant, gmelin, stockhausen, evgeny, yao, beac, cromarty, four,
# Nearest to is: leaching, propane, sweeter, diffeomorphism, jacobus, sturmgewehr, denominators, competences,
# Nearest to operations: generalizes, brute, ogpu, deployable, paigc, operation, divisor, sitcoms,
# Nearest to smith: gophers, downey, conger, mormon, paycheck, intermittent, lodger, benchley,
# Nearest to stage: cooley, srpska, libration, splices, nationalrat, boasting, synth, ottonian,
# Nearest to pope: benedict, patriarch, papal, mehmed, papacy, pius, schism, khayy,
# Nearest to applied: pathogens, benzoyl, hose, nylon, odometer, extrinsic, myelinated, capitalised,
# Nearest to engineering: biomedical, matador, agricultural, prerequisite, postgraduate, marketable, postmodernism, puget,
# Nearest to bill: booker, carr, handlers, garnered, rumsfeld, fathering, session, congregation,
# Nearest to cost: costs, abl, ayrton, visibly, andrey, compensated, frankenchrist, oncoming,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.6580 0.1051 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 3.7730 0.1030 sec/batch
# ...
# Nearest to pope: benedict, xvi, innocent, papal, patriarch, pius, antipope, lateran,
# Nearest to applied: pathogens, nylon, hose, benzoyl, odometer, kam, backdoor, extrinsic,
# Nearest to engineering: biomedical, engineer, technology, rensselaer, engineers, ashford, prerequisite, luminary,
# Nearest to bill: booker, carr, cullen, handlers, plume, renouf, approves, zebra,
# Nearest to cost: costs, marginal, ayrton, cheaper, dollars, eurofighter, compensated, abl,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.5369 0.1043 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.5591 0.1023 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.5470 0.1022 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.5590 0.1037 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.5431 0.1023 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5592 0.1025 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.5513 0.1030 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.5249 0.1016 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.5787 0.1025 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.5590 0.1022 sec/batch
# Nearest to more: handful, elegiac, than, misheard, niklas, ebirah, nanoscale, ibs,
# Nearest to while: raj, natalia, dependability, styrian, aquatic, fraudulently, multicoloured, technically,
# Nearest to zero: estimated, total, populism, imp, yzerman, migrant, organisers, two,
# Nearest to an: linkin, homology, baseketball, gatsby, polypropylene, singlet, tamburlaine, hauptmann,
# Nearest to at: least, lambasted, fdl, saladin, wikisource, diligent, transitory, ashoka,
# Nearest to who: keg, dolmen, iss, ancient, non, nesmith, peterborough, someone,
# Nearest to eight: beac, bryant, cromarty, ingersoll, gmelin, volumes, arae, tagore,
# Nearest to is: propane, southwest, repertory, diffeomorphism, foregone, jacobus, lanka, gower,
# Nearest to operations: operation, agents, brute, ogpu, generalizes, strengths, federative, deployable,
# Nearest to smith: gophers, wagstaff, mormon, downey, lodger, benchley, inexplicably, conger,
# Nearest to stage: cooley, srpska, splices, synth, libration, synclavier, ottonian, webern,
# Nearest to pope: benedict, xvi, innocent, papal, patriarch, pius, lateran, antipope,
# Nearest to applied: pathogens, nylon, hose, benzoyl, kam, backdoor, extrinsic, homeland,
# Nearest to engineering: biomedical, engineer, rensselaer, technology, ashford, engineers, zener, agricultural,
# Nearest to bill: booker, carr, cullen, handlers, plume, renouf, reals, blackwater,
# Nearest to cost: costs, ayrton, marginal, cheaper, eurofighter, dollars, compensated, planners,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.5695 0.1044 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.5423 0.1022 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.5224 0.1033 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.5350 0.1020 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.5846 0.1036 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5177 0.1042 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.6619 0.1031 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5716 0.1026 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.6109 0.1027 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.4946 0.1028 sec/batch
# Nearest to more: handful, than, elegiac, misheard, niklas, ebirah, peasant, ibs,
# Nearest to while: natalia, raj, dependability, birkbeck, fraudulently, impairing, styrian, morales,
# Nearest to zero: estimated, total, migrant, imp, two, tachelhit, fertility, haitham,
# Nearest to an: linkin, homology, baseketball, gatsby, polypropylene, tamburlaine, singlet, willey,
# Nearest to at: least, lambasted, diligent, fdl, saladin, navigated, wikisource, transitory,
# Nearest to who: ancient, keg, dolmen, iss, non, peterborough, wipo, nesmith,
# Nearest to eight: beac, bryant, cromarty, ingersoll, volumes, gmelin, tagore, four,
# Nearest to is: propane, lanka, diffeomorphism, southwest, repertory, tortola, jacobus, denominators,
# Nearest to operations: agents, operation, ogpu, brute, generalizes, strengths, deployable, idempotent,
# Nearest to smith: mormon, gophers, downey, wagstaff, thrusting, inexplicably, lodger, liberalisation,
# Nearest to stage: cooley, srpska, splices, synth, synclavier, libration, ottonian, naissus,
# Nearest to pope: benedict, xvi, innocent, papal, antipope, lateran, pius, schism,
# Nearest to applied: pathogens, nylon, hose, benzoyl, backdoor, homeland, extrinsic, kam,
# Nearest to engineering: biomedical, engineer, rensselaer, technology, ashford, engineers, prerequisite, shinai,
# Nearest to bill: booker, carr, cullen, handlers, initiative, writable, approves, reals,
# Nearest to cost: costs, ayrton, marginal, eurofighter, cheaper, dollars, andrey, compensated,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.4845 0.1031 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.5704 0.1025 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4709 0.1030 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5483 0.1033 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.5459 0.1025 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.5264 0.1022 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5753 0.0588 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.5220 0.1025 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.5661 0.1036 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.5061 0.1031 sec/batch
# Nearest to more: handful, elegiac, than, misheard, niklas, ebirah, ibs, paganini,
# Nearest to while: natalia, raj, styrian, dependability, aquatic, birkbeck, fraudulently, divides,
# Nearest to zero: estimated, total, migrant, yzerman, imp, ashes, two, tachelhit,
# Nearest to an: linkin, homology, polypropylene, baseketball, gatsby, tighter, tamburlaine, detonated,
# Nearest to at: least, lambasted, diligent, fdl, saladin, navigated, tradeoffs, wikisource,
# Nearest to who: keg, iss, ancient, dolmen, non, nesmith, clinker, snipers,
# Nearest to eight: bryant, gmelin, beac, ingersoll, cromarty, tagore, ousterhout, evgeny,
# Nearest to is: propane, southwest, lanka, repertory, tortola, exploded, jacobus, shocking,
# Nearest to operations: operation, agents, generalizes, brute, ogpu, strengths, idempotent, federative,
# Nearest to smith: gophers, mormon, wagstaff, downey, thrusting, inexplicably, lodger, sherwin,
# Nearest to stage: cooley, srpska, splices, libration, synclavier, synth, metastability, ailment,
# Nearest to pope: benedict, xvi, innocent, papal, pius, antipope, viii, lateran,
# Nearest to applied: hose, pathogens, nylon, backdoor, benzoyl, homeland, jujutsu, kam,
# Nearest to engineering: biomedical, engineer, technology, rensselaer, ashford, engineers, shinai, zener,
# Nearest to bill: booker, carr, cullen, handlers, initiative, blackwater, approves, donors,
# Nearest to cost: costs, marginal, dollars, ayrton, cheaper, eurofighter, andrey, abl,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.5025 0.1035 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.5067 0.1022 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.5179 0.1022 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.5064 0.1020 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.5325 0.1022 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.5366 0.1021 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.5724 0.1023 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4441 0.1035 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.4987 0.1028 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.4856 0.1024 sec/batch
# Nearest to more: handful, than, misheard, elegiac, ibs, ebirah, niklas, microbial,
# Nearest to while: natalia, dependability, raj, styrian, aquatic, fraudulently, birkbeck, treat,
# Nearest to zero: estimated, total, yzerman, migrant, imp, tachelhit, ashes, populism,
# Nearest to an: linkin, homology, baseketball, polypropylene, tighter, bootable, tamburlaine, gatsby,
# Nearest to at: least, lambasted, fdl, saladin, diligent, tradeoffs, wikisource, navigated,
# Nearest to who: dolmen, ancient, non, keg, iss, someone, clinker, nesmith,
# Nearest to eight: cromarty, beac, bryant, garment, gmelin, ingersoll, arae, instruction,
# Nearest to is: propane, southwest, repertory, lanka, diffeomorphism, jacobus, tortola, exploded,
# Nearest to operations: operation, generalizes, brute, ogpu, agents, idempotent, strengths, federative,
# Nearest to smith: gophers, mormon, wagstaff, downey, thrusting, sherwin, lewd, benchley,
# Nearest to stage: cooley, srpska, splices, synth, libration, synclavier, ottonian, metastability,
# Nearest to pope: benedict, innocent, xvi, lateran, pius, papal, antipope, patriarch,
# Nearest to applied: hose, pathogens, nylon, benzoyl, odometer, homeland, kuznetsova, jujutsu,
# Nearest to engineering: biomedical, engineer, engineers, rensselaer, technology, ashford, shinai, zener,
# Nearest to bill: booker, carr, cullen, initiative, handlers, renouf, blackwater, datapoint,
# Nearest to cost: costs, marginal, ayrton, cheaper, dollars, eurofighter, abl, dozen,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.4438 0.1034 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.5211 0.1021 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.5224 0.1027 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.4959 0.1027 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.5100 0.1033 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.5766 0.1024 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.5141 0.1028 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.5173 0.1017 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.5356 0.1027 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.5200 0.1021 sec/batch
# Nearest to more: handful, elegiac, than, misheard, niklas, ebirah, ibs, peasant,
# Nearest to while: natalia, raj, dependability, unwavering, styrian, treat, divides, aquatic,
# Nearest to zero: estimated, total, imp, yzerman, ashes, migrant, tachelhit, two,
# Nearest to an: linkin, homology, baseketball, polypropylene, tamburlaine, singlet, tighter, gatsby,
# Nearest to at: least, lambasted, saladin, fdl, tradeoffs, wikisource, diligent, bred,
# Nearest to who: dolmen, nesmith, non, iss, ancient, keg, clinker, fluids,
# Nearest to eight: bryant, cromarty, beac, ingersoll, ousterhout, gmelin, arae, volumes,
# Nearest to is: propane, repertory, jacobus, southwest, gower, diffeomorphism, foregone, lanka,
# Nearest to operations: brute, ogpu, agents, generalizes, operation, strengths, federative, paigc,
# Nearest to smith: gophers, wagstaff, downey, mormon, freeview, thrusting, lodger, inexplicably,
# Nearest to stage: cooley, splices, srpska, synth, synclavier, libration, ottonian, metastability,
# Nearest to pope: benedict, innocent, xvi, lateran, gregory, papal, patriarch, antipope,
# Nearest to applied: hose, pathogens, nylon, benzoyl, kam, kuznetsova, extrinsic, odometer,
# Nearest to engineering: biomedical, engineer, technology, ashford, rensselaer, engineers, zener, shinai,
# Nearest to bill: booker, carr, cullen, handlers, writable, initiative, datapoint, already,
# Nearest to cost: costs, marginal, ayrton, cheaper, dollars, eurofighter, abl, reasonable,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.5186 0.1043 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.5479 0.1025 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.4863 0.1028 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.5052 0.1024 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.5637 0.1017 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.5154 0.1029 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.5284 0.1026 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.5252 0.1025 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.4824 0.1024 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.5177 0.1026 sec/batch
# Nearest to more: handful, than, misheard, elegiac, ebirah, niklas, ibs, nanoscale,
# Nearest to while: natalia, raj, dependability, unwavering, styrian, divides, birkbeck, technically,
# Nearest to zero: estimated, imp, ashes, yzerman, tachelhit, total, circa, populism,
# Nearest to an: linkin, homology, tighter, polypropylene, baseketball, bootable, hurrians, tamburlaine,
# Nearest to at: least, lambasted, fdl, saladin, diligent, bred, tradeoffs, navigated,
# Nearest to who: ancient, non, dolmen, iss, snipers, nesmith, someone, keg,
# Nearest to eight: beac, bryant, cromarty, instruction, four, volumes, hexadecimal, ingersoll,
# Nearest to is: propane, southwest, repertory, jacobus, exploded, lanka, foregone, gower,
# Nearest to operations: brute, ogpu, generalizes, operation, agents, federative, strengths, paigc,
# Nearest to smith: wagstaff, gophers, downey, mormon, thrusting, liberalisation, freeview, lodger,
# Nearest to stage: cooley, splices, srpska, synth, synclavier, libration, ottonian, cranes,
# Nearest to pope: benedict, xvi, innocent, lateran, gregory, papal, viii, patriarch,
# Nearest to applied: pathogens, hose, nylon, homeland, benzoyl, backdoor, kuznetsova, kam,
# Nearest to engineering: biomedical, engineer, technology, ashford, rensselaer, engineers, shinai, zener,
# Nearest to bill: booker, carr, cullen, handlers, writable, approves, initiative, already,
# Nearest to cost: costs, marginal, ayrton, cheaper, eurofighter, dollars, abl, reasonable,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.5464 0.1041 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.4987 0.1038 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.5935 0.1022 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.5981 0.1024 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.5687 0.1017 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.5243 0.1029 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.4645 0.1021 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.5343 0.1013 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.4536 0.1024 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.5560 0.1032 sec/batch
# Nearest to more: handful, than, elegiac, misheard, niklas, ibs, ebirah, paganini,
# Nearest to while: natalia, dependability, raj, birkbeck, styrian, unwavering, divides, fraudulently,
# Nearest to zero: estimated, total, imp, migrant, yzerman, ashes, tachelhit, two,
# Nearest to an: linkin, homology, tighter, baseketball, polypropylene, gatsby, tamburlaine, bootable,
# Nearest to at: least, lambasted, diligent, fdl, tradeoffs, anthology, navigated, bred,
# Nearest to who: ancient, dolmen, snipers, non, keg, iss, nesmith, wipo,
# Nearest to eight: bryant, cromarty, beac, tagore, volumes, ingersoll, arae, gmelin,
# Nearest to is: propane, southwest, repertory, jacobus, lanka, foregone, gower, diffeomorphism,
# Nearest to operations: ogpu, agents, brute, generalizes, operation, strengths, federative, idempotent,
# Nearest to smith: gophers, wagstaff, mormon, downey, thrusting, freeview, lodger, liberalisation,
# Nearest to stage: cooley, synth, splices, srpska, synclavier, libration, eject, cranes,
# Nearest to pope: benedict, xvi, innocent, papal, lateran, gregory, antipope, xiii,
# Nearest to applied: hose, pathogens, nylon, homeland, benzoyl, jujutsu, kuznetsova, kam,
# Nearest to engineering: biomedical, engineer, technology, ashford, rensselaer, shinai, engineers, zener,
# Nearest to bill: booker, carr, cullen, initiative, writable, approves, handlers, blackwater,
# Nearest to cost: costs, marginal, cheaper, dollars, eurofighter, ayrton, abl, reasonable,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.5186 0.1043 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.5322 0.1028 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
